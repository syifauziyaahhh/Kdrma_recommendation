# %% [markdown]
# # **LATAR BELAKANG**
#
# ---
# Drama Korea diterima dengan baik tidak hanya oleh orang Korea tetapi juga oleh orang-orang di seluruh dunia, berkat beragam tema dan elemen menarik yang dihadirkan. Selain konten drama itu sendiri, berbagai faktor seperti sutradara, penyiar, dan jadwal tayang juga memainkan peran penting dalam kesuksesan sebuah drama. Analisis ini menggunakan data dari berbagai drama Korea terkenal untuk melakukan eksplorasi elemen-elemen yang berkontribusi pada popularitas mereka. Seperti yang disebutkan sebelumnya, drama Korea menerima banyak perhatian dan cinta dari seluruh dunia. Mempertimbangkan hasil analisis data, lebih mudah untuk memahami karakteristik drama Korea, dan hasil yang lebih baik dapat diperoleh dengan merujuknya ke produksi drama.

# %% [markdown]
# # **Contents**
#
# ---
# 1. Released Year and Aired On
# 2. Number of Episode Distribution
# 3. Distribution of Korean Drama on different Networks
# 4. Kdrama Duration Distribution
# 5. Korean Drama relased by Year and Content Rating
# 6. Genre Distribution and Top 10 Cast Distribution
# 7. Drama Rating
# 8. Actors and Actresses in the Drama
# 9. Korean Drama Recommendation System

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Loading Dataset**

# %%
df = pd.read_csv('kdrama.csv', header=0)
df.head()
# Out:
#                   Name                   Aired Date  Year of release  \
# 0       Move to Heaven                 May 14, 2021             2021
# 1       Flower of Evil  Jul 29, 2020 - Sep 23, 2020             2020
# 2    Hospital Playlist  Mar 12, 2020 - May 28, 2020             2020
# 3  Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 4            My Mister  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  Number of Episodes       Duration  \
# 0          Netflix                Friday                  10        52 min.
# 1              tvN   Wednesday, Thursday                  16  1 hr. 10 min.
# 2   Netflix,  tvN               Thursday                  12  1 hr. 30 min.
# 3   Netflix,  tvN               Thursday                  12  1 hr. 40 min.
# 4              tvN   Wednesday, Thursday                  16  1 hr. 17 min.
#
#                           Content Rating  Rating  \
# 0  18+ Restricted (violence & profanity)     9.2
# 1                15+ - Teens 15 or older     9.1
# 2                15+ - Teens 15 or older     9.1
# 3                15+ - Teens 15 or older     9.1
# 4                15+ - Teens 15 or older     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                      Genre  \
# 0                   Life,  Drama,  Family
# 1  Thriller,  Romance,  Crime,  Melodrama
# 2   Friendship,  Romance,  Life,  Medical
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family
#
#                                                 Tags  \
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...
# 1  Married Couple, Deception, Suspense, Family Se...
# 2  Strong Friendship, Multiple Mains, Best Friend...
# 3  Workplace, Strong Friendship, Best Friends, Mu...
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...
#
#                      Director    Screenwriter  \
# 0                 Kim Sung Ho    Yoon Ji Ryun
# 1  Kim Chul Gyu, Yoon Jong Ho    Yoo Jung Hee
# 2                 Shin Won Ho    Lee Woo Jung
# 3                 Shin Won Ho    Lee Woo Jung
# 4   Kim Won Suk, Kim Sang Woo  Park Hae Young
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 2  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                    Production companies Rank
# 0  Page One Film, Number Three Pictures   #1
# 1                         Monster Union   #2
# 2                 Egg Is Coming, CJ ENM   #3
# 3                 Egg Is Coming, CJ ENM   #4
# 4                      Chorokbaem Media   #5

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    object
#  1   Aired Date            250 non-null    object
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    object
#  4   Aired On              250 non-null    object
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    object
#  7   Content Rating        245 non-null    object
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    object
#  10  Genre                 250 non-null    object
#  11  Tags                  250 non-null    object
#  12  Director              249 non-null    object
#  13  Screenwriter          249 non-null    object
#  14  Cast                  250 non-null    object
#  15  Production companies  248 non-null    object
#  16  Rank                  250 non-null    object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 33.3+ KB

# %%
df.shape
# Out:
# (250, 17)

# %%
df.columns
# Out:
# Index(['Name', 'Aired Date', 'Year of release', 'Original Network', 'Aired On',
#        'Number of Episodes', 'Duration', 'Content Rating', 'Rating',
#        'Synopsis', 'Genre', 'Tags', 'Director', 'Screenwriter', 'Cast',
#        'Production companies', 'Rank'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name                    0
# Aired Date              0
# Year of release         0
# Original Network        0
# Aired On                0
# Number of Episodes      0
# Duration                0
# Content Rating          5
# Rating                  0
# Synopsis                0
# Genre                   0
# Tags                    0
# Director                1
# Screenwriter            1
# Cast                    0
# Production companies    2
# Rank                    0
# dtype: int64

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# **Released Year and Aired On**
#
# ---

# %%
kdrama_grouped = df.groupby('Year of release').size().reset_index(name='Count')
plt.figure(figsize=(10, 5))
sns.set(style="whitegrid")
barplot = sns.barplot(data=kdrama_grouped, x='Year of release', y='Count', palette="summer_r")
for bar in barplot.patches:
    bar_height = bar.get_height()  # Get the height of the bar
    bar_x = bar.get_x() + bar.get_width() / 2  # Get the x position of the bar
    bar_y = bar_height  # y position to place the text
    plt.text(bar_x, bar_y, int(bar_height), ha='center', va='bottom', fontsize=10)
plt.title('Korean Drama Released by Year', fontsize=16, fontweight='bold')
plt.xlabel('Year of Release', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-152-54b004697a02>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objects as go
fig = px.bar(data_frame = df.groupby(['Year of release','Aired On']).size().reset_index().rename(columns = {0:'Count'}),
             x = 'Year of release',
             y = 'Count',
             color = 'Aired On',
             barmode = 'stack',
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig.update_layout(title = {'text':'Korean Drama relased by Year and Aired On',
                           'y' : 0.95,
                           'x' : 0.45,
                           'xanchor' : 'center',
                           'yanchor' : 'top',
                           'font_family': 'Gravity One, monospace',
                           'font_color' :'black',
                           'font_size': 20},
                  legend_title = 'Aired On (day of week)',
                  font = dict(family = 'Courier New, monospace',
                              size = 15,
                              color = 'midnightblue'
                  ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="23f2aeea-4283-42dc-a25d-e58317162a58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23f2aeea-4283-42dc-a25d-e58317162a58")) {                    Plotly.newPlot(                        "23f2aeea-4283-42dc-a25d-e58317162a58",                        [{"alignmentgroup":"True","hovertemplate":"Aired On= Monday, Tuesday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Monday, Tuesday","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":" Monday, Tuesday","offsetgroup":" Monday, Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":[2003,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1,2,1,1,2,5,1,2,6,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Monday, Tuesday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday, Tuesday","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Monday, Tuesday","offsetgroup":"Monday, Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2009,2010,2013,2014,2015,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1,1,1,1,3,2,2,2,6,4,5,4,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Wednesday, Thursday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday, Thursday","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Wednesday, Thursday","offsetgroup":"Wednesday, Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4,3,2,1,1,2,4,3,11,4,2,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On= Wednesday, Thursday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Wednesday, Thursday","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":" Wednesday, Thursday","offsetgroup":" Wednesday, Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1,3,1,1,2,4,5,1,2,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Saturday, Sunday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday, Sunday","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"Saturday, Sunday","offsetgroup":"Saturday, Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":[2012,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1,1,4,3,3,3,5,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Sunday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":[2012,2019],"xaxis":"x","y":[1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Tuesday\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":[2012,2020],"xaxis":"x","y":[1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aired On=Monday, Tuesday, Wednesday,  ...

# %% [markdown]
# **Number of episodes**
#
# ---

# %%
df['Number of Episodes'].value_counts()
# Out:
# Number of Episodes
# 16     115
# 20      29
# 12      26
# 32      16
# 6        9
# 10       7
# 8        6
# 24       5
# 14       5
# 40       4
# 17       3
# 18       3
# 54       2
# 11       2
# 13       2
# 21       2
# 62       1
# 81       1
# 1        1
# 4        1
# 133      1
# 60       1
# 28       1
# 9        1
# 30       1
# 100      1
# 52       1
# 51       1
# 50       1
# 36       1
# Name: count, dtype: int64

# %%
episodes_count = df['Number of Episodes'].value_counts().sort_values(ascending=False)
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x=episodes_count.index, y=episodes_count.values, palette="winter")
plt.xticks(rotation=90)
plt.xlabel("Num Ep", fontsize=10)
plt.ylabel("Count", fontsize=10)
plt.title("Number of Episode Distribution", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-151-7a844e5991ff>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Original Network**
#
# ---

# %%
df['Original Network'].value_counts()
# Out:
# Original Network
# tvN                       49
# SBS                       30
# MBC                       26
# KBS2                      25
# OCN                       19
# Netflix,  tvN             16
# jTBC                      15
# Netflix                   12
# Netflix, tvN               8
# jTBC, Netflix              4
# Netflix, SBS               4
# MBC, Netflix               3
# Netflix,  SBS              2
# jTBC,  Netflix             2
# YouTube                    2
# iQiyi, tvN                 2
# jTBC, Viki                 2
# Wavve                      2
# Viki                       1
# Naver TV Cast              1
# iQiyi, KBS2, Viki          1
# Channel A                  1
# Hulu                       1
# SBS, ViuTV                 1
# MBN                        1
# TV Chosun                  1
# Daum Kakao TV              1
# KBS2, Netflix              1
# Apple TV+                  1
# Disney+                    1
# Daum Kakao TV, Netflix     1
# MBC, ViuTV                 1
# tvN, ViuTV                 1
# KBS2, ViuTV                1
# iQiyi, jTBC                1
# ENA, Olleh TV              1
# OCN, tvN                   1
# KBS2,  Netflix             1
# ViuTV                      1
# jTBC,  Viki                1
# Hulu, MBC                  1
# Netflix,  OCN              1
# MBC, Viki                  1
# ENA, Netflix               1
# Naver TV Cast, vLive       1
# Name: count, dtype: int64

# %%
# Counting individual network
from collections import Counter

network_list = []
for networks in df['Original Network'] .to_list():
    networks = networks.strip().split(", ")
    for network in networks:
        network_list.append(network)

network_df = pd.DataFrame.from_dict(Counter(network_list),orient='index').rename(columns={0:'Count'})
network_df.sort_values(by='Count',ascending = False,inplace = True)
network_df
# Out:
#                Count
# tvN               61
# Netflix           53
# SBS               35
# MBC               32
# KBS2              29
# jTBC              25
# OCN               20
#  tvN              16
# Viki               5
# ViuTV              5
# iQiyi              4
#  Netflix           3
# Naver TV Cast      2
# YouTube            2
# Daum Kakao TV      2
# Hulu               2
#  SBS               2
# ENA                2
# Wavve              2
#  Viki              1
#  OCN               1
# Olleh TV           1
# Apple TV+          1
# Disney+            1
# Channel A          1
# MBN                1
# TV Chosun          1
# vLive              1

# %%
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(x=network_df.index, y='Count', data=network_df)
plt.title("Distribution of Korean Drama on Different Networks", fontsize=16)
plt.xlabel("Network", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Duration of each episode**
#
# ---

# %%
duration_count = df['Duration'].value_counts().sort_values(ascending=False)
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x=duration_count.index, y=duration_count.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Num Ep", fontsize=10)
plt.ylabel("Count", fontsize=10)
plt.title("Kdrama Duration Distribution", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-149-102399bed15c>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Content Rating**
#
# ---

# %%
content_rating = df['Content Rating'].value_counts().sort_values(ascending=False)
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x=content_rating .index, y=content_rating .values, palette="magma")
plt.xticks(rotation=45)
plt.xlabel("Con Rate", fontsize=10)
plt.ylabel("Count", fontsize=10)
plt.title("Content Rating", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-148-bc9fdef0edb3>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Content Rating by year
fig = px.bar(data_frame = df.groupby(['Year of release','Content Rating']).size().reset_index().rename(columns = {0:'Count'}),
             x = 'Year of release',
             y = 'Count',
             color = 'Content Rating',
             barmode = 'stack',
             color_discrete_sequence=px.colors.qualitative.Pastel_r)

fig.update_layout(title = {'text':'Korean Drama relased by Year and Content Rating',
                           'y' : 0.95,
                           'x' : 0.45,
                           'xanchor' : 'center',
                           'yanchor' : 'top',
                           'font_family': 'Gravity One, monospace',
                           'font_color' :'black',
                           'font_size': 20},
                  legend_title = 'Content Rating 🤭🔥',
                  font = dict(family = 'Courier New, monospace',
                              size = 15,
                              color = 'midnightblue'
                  ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="426b91e3-a4ec-419e-a33c-44aa2cbb4ca8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("426b91e3-a4ec-419e-a33c-44aa2cbb4ca8")) {                    Plotly.newPlot(                        "426b91e3-a4ec-419e-a33c-44aa2cbb4ca8",                        [{"alignmentgroup":"True","hovertemplate":"Content Rating=13+ - Teens 13 or older\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"13+ - Teens 13 or older","marker":{"color":"rgb(179, 179, 179)","pattern":{"shape":""}},"name":"13+ - Teens 13 or older","offsetgroup":"13+ - Teens 13 or older","orientation":"v","showlegend":true,"textposition":"auto","x":[2003,2015,2019,2021,2022],"xaxis":"x","y":[1,2,1,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Content Rating=15+ - Teens 15 or older\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"15+ - Teens 15 or older","marker":{"color":"rgb(180, 151, 231)","pattern":{"shape":""}},"name":"15+ - Teens 15 or older","offsetgroup":"15+ - Teens 15 or older","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1,1,1,1,4,7,11,5,7,13,26,22,35,31,28,23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Content Rating=18+ Restricted (violence & profanity)\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"18+ Restricted (violence & profanity)","marker":{"color":"rgb(139, 224, 164)","pattern":{"shape":""}},"name":"18+ Restricted (violence & profanity)","offsetgroup":"18+ Restricted (violence & profanity)","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2018,2019,2020,2021,2022],"xaxis":"x","y":[1,1,1,4,7,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Content Rating=G - All Ages\u003cbr\u003eYear of release=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"G - All Ages","marker":{"color":"rgb(201, 219, 116)","pattern":{"shape":""}},"name":"G - All Ages","offsetgroup":"G - All Ages","orientation":"v","showlegend":true,"textposition":"auto","x":[2021],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11 ...

# %% [markdown]
# **Genres**
#
# ---

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Romance, Life, Drama, Melodrama             5
# Comedy, Romance, Drama                      4
# Thriller, Mystery, Drama                    4
# Psychological,  Comedy,  Romance,  Drama    4
# Thriller,  Mystery,  Law,  Drama            3
#                                            ..
# Comedy,  Romance,  Drama,  Supernatural     1
# Mystery,  Comedy,  Family,  Fantasy         1
# Friendship,  Romance,  Life,  Youth         1
# Psychological,  Romance,  Melodrama         1
# Horror, Comedy, Romance, Fantasy            1
# Name: count, Length: 201, dtype: int64

# %%
# Counting individual genre
from collections import Counter

genre_list = []
for genre in df['Genre'] .to_list():
    genre = genre.strip().split(", ")
    for genre in genre:
        genre_list.append(genre)

genre_df = pd.DataFrame.from_dict(Counter(genre_list),orient='index').rename(columns={0:'Count'})
genre_df.sort_values(by='Count',ascending = False,inplace = True)
genre_df
# Out:
#                 Count
# Romance            90
# Drama              78
# Thriller           74
# Comedy             67
# Mystery            65
#  Drama             51
#  Romance           46
# Action             45
# Life               30
# Melodrama          29
# Historical         27
#  Mystery           25
# Fantasy            23
#  Comedy            21
# Law                19
#  Life              15
#  Family            15
#  Melodrama         14
#  Crime             13
# Psychological      13
# Crime              13
# Supernatural       12
#  Thriller          12
# Youth              12
#  Supernatural      12
#  Fantasy           11
#  Political         10
# Friendship          9
# Medical             8
# Political           8
#  Law                8
#  Historical         7
#  Medical            7
# Horror              7
# Business            7
#  Psychological      6
# Sci-Fi              6
#  Sci-Fi             5
#  Youth              5
# Music               4
#  Horror             4
#  Sports             4
# Military            3
# Adventure           3
# Food                2
#  Business           2
#  School             2
# Sports              2
#  Military           1
# Sitcom              1

# %%
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
barplot = sns.barplot(x=genre_df.index, y='Count', data=genre_df, palette="Set2")
plt.title('Genre Distribution', fontsize=20, fontweight='bold')
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-146-8c8829e7f49f>:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Individuals Tags
tags_list = list()

for tags in df['Tags'].to_list():
    tags = tags.split(", ")
    for tag in tags:
        tags_list.append(tag)

tags_df = pd.DataFrame.from_dict(Counter(tags_list), orient = 'index').rename(columns = {0:'Count'})
tags_df.sort_values(by='Count',ascending = False, inplace = True)
tags_df.head()
# Out:
#                     Count
# Strong Female Lead     98
# Smart Female Lead      49
# Smart Male Lead        46
# Nice Male Lead         45
# Bromance               44

# %%
# Ambil 10 baris pertama dari DataFrame
top_tags = tags_df.head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_tags.index, top_tags['Count'])
plt.title('Top 10 Cast Distribution')
plt.xlabel('tags')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Drama Rating**
#
# ---

# %%
# Max and Min Rating in the Top 100 Korean Drama
df['Rating'].max(), df['Rating'].min()
# Out:
# (9.2, 8.3)

# %%
# Best Drama Rating
df[df['Rating'] == df['Rating'].max()]
# Out:
#              Name    Aired Date  Year of release Original Network Aired On  \
# 0  Move to Heaven  May 14, 2021             2021          Netflix   Friday
#
#    Number of Episodes Duration                         Content Rating  Rating  \
# 0                  10  52 min.  18+ Restricted (violence & profanity)     9.2
#
#                                             Synopsis                  Genre  \
# 0  Geu Roo is a young autistic man. He works for ...  Life,  Drama,  Family
#
#                                                 Tags     Director  \
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...  Kim Sung Ho
#
#    Screenwriter                                               Cast  \
# 0  Yoon Ji Ryun  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
#
#                    Production companies Rank
# 0  Page One Film, Number Three Pictures   #1

# %%
df[df['Rating'] == df['Rating'].min()].head()
# Out:
#                                Name                   Aired Date  \
# 185                   Class of Lies   Jul 17, 2019 - Sep 5, 2019
# 186              100 Days My Prince  Sep 10, 2018 - Oct 30, 2018
# 187  At a Distance, Spring Is Green  Jun 14, 2021 - Jul 20, 2021
# 188                   Lie After Lie   Sep 4, 2020 - Oct 24, 2020
# 189              The Sound of Magic                  May 6, 2022
#
#      Year of release   Original Network             Aired On  \
# 185             2019                OCN  Wednesday, Thursday
# 186             2018                tvN      Monday, Tuesday
# 187             2021  iQiyi, KBS2, Viki      Monday, Tuesday
# 188             2020          Channel A     Friday, Saturday
# 189             2022            Netflix               Friday
#
#      Number of Episodes       Duration           Content Rating  Rating  \
# 185                  16  1 hr. 10 min.  15+ - Teens 15 or older     8.3
# 186                  16  1 hr. 15 min.  15+ - Teens 15 or older     8.3
# 187                  12   1 hr. 3 min.  15+ - Teens 15 or older     8.3
# 188                  16   1 hr. 9 min.  15+ - Teens 15 or older     8.3
# 189                   6  1 hr. 10 min.  15+ - Teens 15 or older     8.3
#
#                                               Synopsis  \
# 185  The drama is about a highly successful lawyer ...
# 186  Lee Yul, Crown Prince of Joseon, is a perfecti...
# 187  A coming of age story about young people in th...
# 188  Ji Eun Su is a woman who appears to have it al...
# 189  High school student Yoon Ah Yi finances hersel...
#
#                                     Genre  \
# 185         Thriller, Mystery, Law, Youth
# 186    Historical, Comedy, Romance, Drama
# 187                  Romance, Life, Youth
# 188          Thriller, Romance, Melodrama
# 189  Music, Psychological, Drama, Fantasy
#
#                                                   Tags  \
# 185  Murder, Investigation, Death, High School, Jea...
# 186  Amnesia, Hidden Identity, Marriage Of Convenie...
# 187  Coming Of Age, Bromance, Adapted From A Webtoo...
# 188  Nice Male Lead, Father-Daughter Relationship, ...
# 189  Poor Female Lead, Magician Male Lead, Student,...
#
#                        Director              Screenwriter  \
# 185  Sung Yong Il, Park Ji Hyun            Jang Hong Chul
# 186  Lee Jong Jae, Nam Sung Woo                Noh Ji Sul
# 187               Kim Jung Hyun  Ji Nyoong, Jung Won-Jung
# 188               Kim Jung Kwon                Kim Ji Eun
# 189              Kim Seong Yoon              Kim Min Jung
#
#                                                   Cast Production companies  \
# 185  Yoon Kyun Sang, Geum Sae Rok, Lee Jun Young, C...          JS Pictures
# 186  Doh Kyung Soo, Nam Ji Hyun, Kim Seon Ho, Han S...               AStory
# 187  Park Ji Hoon, Kang  Min Ah, Bae In Hyuk, Kwon ...     Victory Contents
# 188  Lee Yoo Ri, Yeon Jung Hoon, Lee Il Hwa, Im Ju ...         Raemongraein
# 189  Ji Chang Wook, Choi Sung Eun, Hwang In Youp, O...    SLL, Zium Content
#
#      Rank
# 185  #186
# 186  #187
# 187  #188
# 188  #189
# 189  #190

# %% [markdown]
# **Actors and Actresses in the Drama**
#
# ---

# %%
cast_list = list()

for casts in df['Cast'].to_list():
    casts = casts.split(", ")
    for a in casts:
        cast_list.append(a)

cast_df = pd.DataFrame.from_dict(Counter(cast_list),orient = 'index').rename(columns = {0:'Appearance'})
cast_df.sort_values(by='Appearance',ascending = False,inplace = True)
cast_df.head()
# Out:
#                 Appearance
# Lee Joon Hyuk            8
# Ahn Bo Hyun              7
# Shin Hye Sun             7
# Kim Ji Won               6
# Park Min Young           6

# %%
# Ambil 10 baris pertama dari DataFrame
top_cast = cast_df.head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_cast.index, top_cast['Appearance'])
plt.title('Top 10 Cast Distribution')
plt.xlabel('Cast')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Korean Drama Recommendation System**
#
# ---

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

features = ['Duration','Synopsis','Cast','Genre','Tags']
df['Number of Episodes'] = df['Number of Episodes'].astype(str)

df['combined_features'] = df['Synopsis'] + " " + df['Genre'] + " " + df['Tags']

cv = CountVectorizer()
count_matrix = cv.fit_transform(df['combined_features'])
cosine_sim = cosine_similarity(count_matrix)

# %%
# Function for movie recommendation
def df_recommendation(mov,sim_num = 5):

    user_choice = mov

    try:
        ref_index = df[df['Name'].str.contains(user_choice, case = False)].index[0]

        similar_movies = list(enumerate(cosine_sim[ref_index]))

        sorted_simmilar_movies = sorted(similar_movies, key = lambda x: x[1], reverse = True)[1:]

        print('\nRecomended K Drama for [{}]'.format(user_choice))
        print('-'*(24 + len(user_choice)))

        for i, element in enumerate(sorted_simmilar_movies):
            similar_movie_id = element[0]
            similar_movie_title = df['Name'].iloc[similar_movie_id]
            s_score = element[1]
            print('{:40} -> {:.3f}'.format(similar_movie_title, s_score))

            if i > sim_num:
                break
    except IndexError:
        print("\n[{}] is not in our database!".format(user_choice))
        print("We couldn't recommend anyting...Sorry...")

# %%
# Search for movie with the keyword
def df_available(key):

    keyword = key

    print("Movie with keyword: [{}]".format(keyword))

    for i, mov in enumerate(df[df['Name'].str.contains(keyword)]['Name'].to_list()):
        print("{}) {} ".format(i+1,mov))

# %%
df_available('It')
# Out:
# Movie with keyword: [It]
# 1) It's Okay to Not Be Okay
# 2) It's Okay, That's Love
# 3) Itaewon Class
# 4) It's Okay, That's Friendship

# %%
df_recommendation("It's Okay to Not Be Okay")
# Out:
# Recomended K Drama for [It's Okay to Not Be Okay]
# ------------------------------------------------
# Two Weeks                                -> 0.404
# Angel's Last Mission: Love               -> 0.382
# Be Melodramatic                          -> 0.379
# Juvenile Justice                         -> 0.360
# Thirty But Seventeen                     -> 0.360
# Vincenzo                                 -> 0.359
# The Beauty Inside                        -> 0.355

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

tfdif_vector = TfidfVectorizer(stop_words = 'english')

tfidf_matrix = tfdif_vector.fit_transform(df['Synopsis'])

sim_matrix = linear_kernel(tfidf_matrix, tfidf_matrix)

indicies = pd.Series(df.index, index = df['Name']).drop_duplicates()

# %%
def content_based_recommender(title, sim_scores = sim_matrix):
    idx = indicies[title]

    sim_scores = list(enumerate(sim_matrix[idx]))

    sim_scores = sorted(sim_scores, key = lambda x : x[1], reverse = True)

    sim_scores = sim_scores[1:11]

    drama_score = list()
    for score in sim_scores:
        drama_score.append(score[1])

    kdrama_indices = [i[0] for i in sim_scores]

    kdrama_name = df['Name'].iloc[kdrama_indices]

    print('\nRecomended KDrama for [{}]'.format(title))
    print('-'*(24 + len(title)))
    for score,name in list(zip(drama_score,kdrama_name)):
        print("{:30} -> {:.3f}".format(name,score))

# %%
content_based_recommender("It's Okay to Not Be Okay")
# Out:
# Recomended KDrama for [It's Okay to Not Be Okay]
# ------------------------------------------------
# While You Were Sleeping        -> 0.116
# Two Weeks                      -> 0.090
# Ghost Doctor                   -> 0.079
# Five Enough                    -> 0.072
# Stranger 2                     -> 0.061
# Healer                         -> 0.061
# Youth of May                   -> 0.056
# Be Melodramatic                -> 0.052
# Children of Nobody             -> 0.051
# The Fiery Priest               -> 0.049

# %%
# nltk
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

VERB_CODES = {'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'}
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def preprocess_sentences(text):
    text = text.lower()
    temp_sent =[]
    words = nltk.word_tokenize(text)
    tags = nltk.pos_tag(words)
    for i, word in enumerate(words):
        if tags[i][1] in VERB_CODES:
              lemmatized = lemmatizer.lemmatize(word, 'v')
        else:
              lemmatized = lemmatizer.lemmatize(word)
        if lemmatized not in stop_words and lemmatized.isalpha():
              temp_sent.append(lemmatized)

    finalsent = ' '.join(temp_sent)
    finalsent = finalsent.replace("n't", " not")
    finalsent = finalsent.replace("'m", " am")
    finalsent = finalsent.replace("'s", " is")
    finalsent = finalsent.replace("'re", " are")
    finalsent = finalsent.replace("'ll", " will")
    finalsent = finalsent.replace("'ve", " have")
    finalsent = finalsent.replace("'d", " would")
    return finalsent

df_copy = df.copy()
df_copy['synopsis_processed'] = df_copy['Synopsis'].apply(preprocess_sentences)
df_copy['synopsis_processed'].head()
# Out:
# 0    geu roo young autistic man work father busines...
# 1    although baek hee sung hide dark secret surrou...
# 2    story people go day seemingly ordinary actuall...
# 3    everyday extraordinary five doctor patient ins...
# 4    park dong hoon engineer marry attorney kang yo...
# Name: synopsis_processed, dtype: object

# %%
tfdifvec = TfidfVectorizer()
tfdif_drama_processed = tfdifvec.fit_transform((df_copy['synopsis_processed']))

co_sin_drama = cosine_similarity(tfdif_drama_processed,tfdif_drama_processed)

# %%
# Storing indices of the data
indices = pd.Series(df_copy['Name'])

def recommendations(title, cosine_sim = co_sin_drama):
    recommended_movies = []
    index = indices[indices == title].index[0]
    similarity_scores = pd.Series(cosine_sim[index]).sort_values(ascending = False)
    top_10_movies = list(similarity_scores.iloc[1:11].index)
    for i in top_10_movies:
        recommended_movies.append(list(df_copy['Name'].index)[i])

    for index in recommended_movies:
        print(df_copy.iloc[index]['Name'])

# %%
recommendations("It's Okay to Not Be Okay")
# Out:
# Ghost Doctor
# The Fiery Priest
# While You Were Sleeping
# Two Weeks
# Voice 4: Judgment Hour
# Children of Nobody
# Stranger 2
# Kill Me, Heal Me
# Healer
# Come and Hug Me

# %% [markdown]
# # **Results and Conclusions**
#
# ---

# %% [markdown]
# **Results:**
#
# - Drama Korea dengan jumlah rilis terbanyak di tahun 2021.
# - Jumlah episode terbanyak pada drama Korea umumnya adalah 16 episode.
# - Distribusi Drama Korea di berbagai jaringan televisi paling dominan ada di TVN.
# - Durasi episode drama Korea yang paling umum adalah 1 jam 10 menit.
# - Genre yang paling populer adalah romance.
# - Drama dengan rating tertinggi adalah **Move to Heaven** dengan nilai 9,2.

# %% [markdown]
# **Conclusions:**
#
# Dari hasil rekomendasi di atas, diketahui bahwa **"It's Okay to Not Be Okay"** memiliki kesamaan dalam kategori Sinopsis, Genre, dan Tags. Dari 7 item yang direkomendasikan, semuanya memiliki kesamaan dalam kategori tersebut. Selain itu, terdapat 10 rekomendasi yang memiliki sinopsis serupa.
